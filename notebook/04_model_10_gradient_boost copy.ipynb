# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import metrics

# %%
df = pd.read_csv('../data/train_data_encoded_full_1.csv')
print('shape:', df.shape)
df.head(5)
# Out:
# shape: (36944, 8)
#    quality  color  clarity  price  weight_ES  depth_percent_ES  \
# 0        3      6        1  6.353  -0.625000          0.357143
# 1        4      5        5  9.183   0.484375          0.571429
# 2        4      4        3  7.983   0.031250         -0.071429
# 3        2      3        1  8.371   0.593750          0.928571
# 4        3      3        4  6.588  -0.531250          0.285714
#
#    table_percent_ES  volume_ES
# 0          0.333333  -0.591767
# 1         -0.333333   0.550637
# 2          0.666667   0.052269
# 3          0.000000   0.624043
# 4          0.666667  -0.511469

# %%
#split dara train and test
X = df.drop(["price"], axis = 1)
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size   = 0.8, random_state = 42)

print("Datos de entrenamiento")
print("-----------------------")
print(y_train.describe())
print('\n')
print("Datos de testeo")
print("-----------------------")
print(y_test.describe())
# Out:
# Datos de entrenamiento
# -----------------------
# count    29555.000000
# mean         7.702645
# std          0.976815
# min          5.814000
# 25%          6.809000
# 50%          7.689000
# 75%          8.505000
# max          9.842000
# Name: price, dtype: float64
#
#
# Datos de testeo
# -----------------------
# count    7389.000000
# mean        7.699702
# std         0.982903
# min         5.787000
# 25%         6.802000
# 50%         7.695000
# 75%         8.511000
# max         9.841000
# Name: price, dtype: float64

# %%
def metricas(y_test, y_train, y_test_pred, y_train_pred, tipo_modelo):
    resultados = {'MAE': [metrics.mean_absolute_error(y_test, y_test_pred), metrics.mean_absolute_error(y_train, y_train_pred)],
                'MSE': [metrics.mean_squared_error(y_test, y_test_pred), metrics.mean_squared_error(y_train, y_train_pred)],
                'RMSE': [np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)), np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))],
                'R2':  [metrics.r2_score(y_test, y_test_pred), metrics.r2_score(y_train, y_train_pred)],
                 "set": ["test", "train"]}
    df = pd.DataFrame(resultados)
    df["modelo"] = tipo_modelo
    return df

# %%
gb = GradientBoostingRegressor(n_estimators=100, loss='squared_error', learning_rate=0.1, max_depth=8, random_state=0, criterion='friedman_mse')
gb.fit(X_train, y_train)

y_pred_gb_test= gb.predict(X_test)
y_pred_gb_train= gb.predict(X_train)

results_gradient_1 = metricas(y_test, y_train, y_pred_gb_test, y_pred_gb_train, "Gradient 1")
results_gradient_1.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_620b5_row0_col0, #T_620b5_row0_col1, #T_620b5_row0_col2, #T_620b5_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_620b5_row0_col3, #T_620b5_row1_col0, #T_620b5_row1_col1, #T_620b5_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_620b5">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_620b5_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_620b5_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_620b5_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_620b5_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_620b5_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_620b5_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_620b5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_620b5_row0_col0" class="data row0 col0" >0.070603</td>
#       <td id="T_620b5_row0_col1" class="data row0 col1" >0.008793</td>
#       <td id="T_620b5_row0_col2" class="data row0 col2" >0.093771</td>
#       <td id="T_620b5_row0_col3" class="data row0 col3" >0.990897</td>
#       <td id="T_620b5_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_620b5_row0_col5" class="data row0 col5" >Gradient 1</td>
#     </tr>
#     <tr>
#       <th id="T_620b5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_620b5_row1_col0" class="data row1 col0" >0.058625</td>
#       <td id="T_620b5_row1_col1" class="data row1 col1" >0.006028</td>
#       <td id="T_620b5_row1_col2" class="data row1 col2" >0.077638</td>
#       <td id="T_620b5_row1_col3" class="data row1 col3" >0.993683</td>
#       <td id="T_620b5_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_620b5_row1_col5" class="data row1 col5" >Gradient 1</td>
#     </tr>
#   </tbody>
# </table>

# %%
gb = GradientBoostingRegressor(n_estimators=120, loss='squared_error', learning_rate=0.1, max_depth=7, random_state=0, criterion='friedman_mse')
gb.fit(X_train, y_train)

y_pred_gb_test= gb.predict(X_test)
y_pred_gb_train= gb.predict(X_train)

results_gradient_2 = metricas(y_test, y_train, y_pred_gb_test, y_pred_gb_train, "Gradient 2")
results_gradient_2.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_8b748_row0_col0, #T_8b748_row0_col1, #T_8b748_row0_col2, #T_8b748_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_8b748_row0_col3, #T_8b748_row1_col0, #T_8b748_row1_col1, #T_8b748_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8b748">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8b748_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_8b748_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_8b748_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_8b748_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_8b748_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_8b748_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8b748_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8b748_row0_col0" class="data row0 col0" >0.070665</td>
#       <td id="T_8b748_row0_col1" class="data row0 col1" >0.008708</td>
#       <td id="T_8b748_row0_col2" class="data row0 col2" >0.093315</td>
#       <td id="T_8b748_row0_col3" class="data row0 col3" >0.990985</td>
#       <td id="T_8b748_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_8b748_row0_col5" class="data row0 col5" >Gradient 2</td>
#     </tr>
#     <tr>
#       <th id="T_8b748_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_8b748_row1_col0" class="data row1 col0" >0.062614</td>
#       <td id="T_8b748_row1_col1" class="data row1 col1" >0.006789</td>
#       <td id="T_8b748_row1_col2" class="data row1 col2" >0.082393</td>
#       <td id="T_8b748_row1_col3" class="data row1 col3" >0.992885</td>
#       <td id="T_8b748_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_8b748_row1_col5" class="data row1 col5" >Gradient 2</td>
#     </tr>
#   </tbody>
# </table>

# %%
gb = GradientBoostingRegressor(n_estimators=125, loss='squared_error', learning_rate=0.15, max_depth=6, random_state=0, criterion='friedman_mse')
gb.fit(X_train, y_train)

y_pred_gb_test= gb.predict(X_test)
y_pred_gb_train= gb.predict(X_train)

results_gradient_3 = metricas(y_test, y_train, y_pred_gb_test, y_pred_gb_train, "Gradient 3")
results_gradient_3.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_1b4a7_row0_col0, #T_1b4a7_row0_col1, #T_1b4a7_row0_col2, #T_1b4a7_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1b4a7_row0_col3, #T_1b4a7_row1_col0, #T_1b4a7_row1_col1, #T_1b4a7_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1b4a7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1b4a7_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_1b4a7_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_1b4a7_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_1b4a7_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_1b4a7_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_1b4a7_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b4a7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b4a7_row0_col0" class="data row0 col0" >0.071491</td>
#       <td id="T_1b4a7_row0_col1" class="data row0 col1" >0.008885</td>
#       <td id="T_1b4a7_row0_col2" class="data row0 col2" >0.094258</td>
#       <td id="T_1b4a7_row0_col3" class="data row0 col3" >0.990802</td>
#       <td id="T_1b4a7_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_1b4a7_row0_col5" class="data row0 col5" >Gradient 3</td>
#     </tr>
#     <tr>
#       <th id="T_1b4a7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b4a7_row1_col0" class="data row1 col0" >0.064578</td>
#       <td id="T_1b4a7_row1_col1" class="data row1 col1" >0.007181</td>
#       <td id="T_1b4a7_row1_col2" class="data row1 col2" >0.084738</td>
#       <td id="T_1b4a7_row1_col3" class="data row1 col3" >0.992474</td>
#       <td id="T_1b4a7_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_1b4a7_row1_col5" class="data row1 col5" >Gradient 3</td>
#     </tr>
#   </tbody>
# </table>

# %%
gb = GradientBoostingRegressor(n_estimators=100, loss='squared_error', learning_rate=0.15, max_depth=7, random_state=0, criterion='squared_error')
gb.fit(X_train, y_train)

y_pred_gb_test= gb.predict(X_test)
y_pred_gb_train= gb.predict(X_train)

results_gradient_4 = metricas(y_test, y_train, y_pred_gb_test, y_pred_gb_train, "Gradient 4")
results_gradient_4.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b18db_row0_col0, #T_b18db_row0_col1, #T_b18db_row0_col2, #T_b18db_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b18db_row0_col3, #T_b18db_row1_col0, #T_b18db_row1_col1, #T_b18db_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b18db">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b18db_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_b18db_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_b18db_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_b18db_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_b18db_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_b18db_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b18db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b18db_row0_col0" class="data row0 col0" >0.070944</td>
#       <td id="T_b18db_row0_col1" class="data row0 col1" >0.008883</td>
#       <td id="T_b18db_row0_col2" class="data row0 col2" >0.094250</td>
#       <td id="T_b18db_row0_col3" class="data row0 col3" >0.990804</td>
#       <td id="T_b18db_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_b18db_row0_col5" class="data row0 col5" >Gradient 4</td>
#     </tr>
#     <tr>
#       <th id="T_b18db_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b18db_row1_col0" class="data row1 col0" >0.061619</td>
#       <td id="T_b18db_row1_col1" class="data row1 col1" >0.006607</td>
#       <td id="T_b18db_row1_col2" class="data row1 col2" >0.081282</td>
#       <td id="T_b18db_row1_col3" class="data row1 col3" >0.993076</td>
#       <td id="T_b18db_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_b18db_row1_col5" class="data row1 col5" >Gradient 4</td>
#     </tr>
#   </tbody>
# </table>

# %%
gb = GradientBoostingRegressor(n_estimators=110, loss='squared_error', learning_rate=0.12, max_depth=7, random_state=0, criterion='squared_error')
gb.fit(X_train, y_train)

y_pred_gb_test= gb.predict(X_test)
y_pred_gb_train= gb.predict(X_train)

results_gradient_5 = metricas(y_test, y_train, y_pred_gb_test, y_pred_gb_train, "Gradient 5")
results_gradient_5.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f8163_row0_col0, #T_f8163_row0_col1, #T_f8163_row0_col2, #T_f8163_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f8163_row0_col3, #T_f8163_row1_col0, #T_f8163_row1_col1, #T_f8163_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f8163">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f8163_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f8163_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f8163_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f8163_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f8163_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_f8163_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f8163_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f8163_row0_col0" class="data row0 col0" >0.070990</td>
#       <td id="T_f8163_row0_col1" class="data row0 col1" >0.008789</td>
#       <td id="T_f8163_row0_col2" class="data row0 col2" >0.093750</td>
#       <td id="T_f8163_row0_col3" class="data row0 col3" >0.990901</td>
#       <td id="T_f8163_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_f8163_row0_col5" class="data row0 col5" >Gradient 5</td>
#     </tr>
#     <tr>
#       <th id="T_f8163_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f8163_row1_col0" class="data row1 col0" >0.062201</td>
#       <td id="T_f8163_row1_col1" class="data row1 col1" >0.006696</td>
#       <td id="T_f8163_row1_col2" class="data row1 col2" >0.081827</td>
#       <td id="T_f8163_row1_col3" class="data row1 col3" >0.992983</td>
#       <td id="T_f8163_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_f8163_row1_col5" class="data row1 col5" >Gradient 5</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_results = pd.concat([results_gradient_1, results_gradient_2, results_gradient_3, results_gradient_4, results_gradient_5], axis = 0)
df_results
# Out:
#         MAE       MSE      RMSE        R2    set      modelo
# 0  0.070603  0.008793  0.093771  0.990897   test  Gradient 1
# 1  0.058625  0.006028  0.077638  0.993683  train  Gradient 1
# 0  0.070665  0.008708  0.093315  0.990985   test  Gradient 2
# 1  0.062614  0.006789  0.082393  0.992885  train  Gradient 2
# 0  0.071491  0.008885  0.094258  0.990802   test  Gradient 3
# 1  0.064578  0.007181  0.084738  0.992474  train  Gradient 3
# 0  0.070944  0.008883  0.094250  0.990804   test  Gradient 4
# 1  0.061619  0.006607  0.081282  0.993076  train  Gradient 4
# 0  0.070990  0.008789  0.093750  0.990901   test  Gradient 5
# 1  0.062201  0.006696  0.081827  0.992983  train  Gradient 5
