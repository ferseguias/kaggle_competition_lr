# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %%
df = pd.read_csv('../data/train_data_encoded.csv')
print('shape:', df.shape)
df.head(5)
# Out:
# shape: (36944, 8)
#    quality  color  clarity  price  weight_ES  depth_percent_ES  \
# 0        3      6        1  6.353  -0.625000          0.357143
# 1        4      5        5  9.183   0.484375          0.571429
# 2        4      4        3  7.983   0.031250         -0.071429
# 3        2      3        1  8.371   0.593750          0.928571
# 4        3      3        4  6.588  -0.531250          0.285714
#
#    table_percent_ES  volume_ES
# 0          0.333333  -0.591767
# 1         -0.333333   0.550637
# 2          0.666667   0.052269
# 3          0.000000   0.624043
# 4          0.666667  -0.511469

# %%
#split dara train and test
X = df.drop(["price"], axis = 1)
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size   = 0.8, random_state = 42)

print("Datos de entrenamiento")
print("-----------------------")
print(y_train.describe())
print('\n')
print("Datos de testeo")
print("-----------------------")
print(y_test.describe())
# Out:
# Datos de entrenamiento
# -----------------------
# count    29555.000000
# mean         7.702645
# std          0.976815
# min          5.814000
# 25%          6.809000
# 50%          7.689000
# 75%          8.505000
# max          9.842000
# Name: price, dtype: float64
#
#
# Datos de testeo
# -----------------------
# count    7389.000000
# mean        7.699702
# std         0.982903
# min         5.787000
# 25%         6.802000
# 50%         7.695000
# 75%         8.511000
# max         9.841000
# Name: price, dtype: float64

# %%
def metricas(y_test, y_train, y_test_pred, y_train_pred, tipo_modelo):
    resultados = {'MAE': [metrics.mean_absolute_error(y_test, y_test_pred), metrics.mean_absolute_error(y_train, y_train_pred)],
                'MSE': [metrics.mean_squared_error(y_test, y_test_pred), metrics.mean_squared_error(y_train, y_train_pred)],
                'RMSE': [np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)), np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))],
                'R2':  [metrics.r2_score(y_test, y_test_pred), metrics.r2_score(y_train, y_train_pred)],
                 "set": ["test", "train"]}
    df = pd.DataFrame(resultados)
    df["modelo"] = tipo_modelo
    return df

# %%
param = {"max_depth": [18],
        "max_features": [15],
        "min_samples_split": [10]}

random_forest = GridSearchCV(
            estimator=RandomForestRegressor(),
            param_grid= param,
            cv=10,
            n_jobs = -1,
            verbose= 3,
            return_train_score = True,
            scoring="neg_mean_squared_error")

random_forest.fit(X_train, y_train)

best_rf = random_forest.best_estimator_
print(best_rf)

y_pred_test_rf = random_forest.predict(X_test)
y_pred_train_rf = random_forest.predict(X_train)
rf_results_1 = metricas(y_test, y_train, y_pred_test_rf, y_pred_train_rf, "Random Forest 1")
rf_results_1.style.background_gradient(cmap='coolwarm')
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# [CV 7/10] END max_depth=18, max_features=15, min_samples_split=10;, score=(train=-0.005, test=-0.011) total time=  23.5s
# [CV 3/10] END max_depth=18, max_features=15, min_samples_split=10;, score=(train=-0.005, test=-0.011) total time=  23.7s
# [CV 1/10] END max_depth=18, max_features=15, min_samples_split=10;, score=(train=-0.005, test=-0.010) total time=  24.1s
# [CV 4/10] END max_depth=18, max_features=15, min_samples_split=10;, score=(train=-0.005, test=-0.011) total time=  24.2s
# [CV 2/10] END max_depth=18, max_features=15, min_samples_split=10;, score=(train=-0.005, test=-0.010) total time=  24.3s
# [CV 5/10] END max_depth=18, max_features=15, min_samples_split=10;, score=(train=-0.005, test=-0.010) total time=  24.5s
# [CV 8/10] END max_depth=18, max_features=15, min_samples_split=10;, score=(train=-0.005, test=-0.011) total time=  24.3s
# [CV 6/10] END max_depth=18, max_features=15, min_samples_split=10;, score=(train=-0.005, test=-0.011) total time=  24.6s
# [CV 9/10] END max_depth=18, max_features=15, min_samples_split=10;, score=(train=-0.005, test=-0.011) total time=  15.7s
# [CV 10/10] END max_depth=18, max_features=15, min_samples_split=10;, score=(train=-0.005, test=-0.011) total time=  15.5s
# RandomForestRegressor(max_depth=18, max_features=15, min_samples_split=10)
# <style type="text/css">
# #T_1bbd0_row0_col0, #T_1bbd0_row0_col1, #T_1bbd0_row0_col2, #T_1bbd0_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_1bbd0_row0_col3, #T_1bbd0_row1_col0, #T_1bbd0_row1_col1, #T_1bbd0_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_1bbd0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1bbd0_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_1bbd0_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_1bbd0_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_1bbd0_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_1bbd0_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_1bbd0_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1bbd0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1bbd0_row0_col0" class="data row0 col0" >0.077406</td>
#       <td id="T_1bbd0_row0_col1" class="data row0 col1" >0.010436</td>
#       <td id="T_1bbd0_row0_col2" class="data row0 col2" >0.102155</td>
#       <td id="T_1bbd0_row0_col3" class="data row0 col3" >0.989197</td>
#       <td id="T_1bbd0_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_1bbd0_row0_col5" class="data row0 col5" >Random Forest 1</td>
#     </tr>
#     <tr>
#       <th id="T_1bbd0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1bbd0_row1_col0" class="data row1 col0" >0.051783</td>
#       <td id="T_1bbd0_row1_col1" class="data row1 col1" >0.004697</td>
#       <td id="T_1bbd0_row1_col2" class="data row1 col2" >0.068537</td>
#       <td id="T_1bbd0_row1_col3" class="data row1 col3" >0.995077</td>
#       <td id="T_1bbd0_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_1bbd0_row1_col5" class="data row1 col5" >Random Forest 1</td>
#     </tr>
#   </tbody>
# </table>

# %%
param = {"max_depth": [15, 18, 22],
        "max_features": [12, 15, 18],
        "min_samples_split": [5, 10, 15]}

random_forest = GridSearchCV(
            estimator=RandomForestRegressor(),
            param_grid= param,
            cv=10,
            n_jobs = -1,
            verbose= 1,
            return_train_score = True,
            scoring="neg_mean_squared_error")

random_forest.fit(X_train, y_train)

best_rf = random_forest.best_estimator_
print(best_rf)

y_pred_test_rf = random_forest.predict(X_test)
y_pred_train_rf = random_forest.predict(X_train)
rf_results_2 = metricas(y_test, y_train, y_pred_test_rf, y_pred_train_rf, "Random Forest 2")
rf_results_2.style.background_gradient(cmap='coolwarm')
# Out:
# Fitting 10 folds for each of 27 candidates, totalling 270 fits
# RandomForestRegressor(max_depth=15, max_features=18, min_samples_split=15)
# <style type="text/css">
# #T_617c8_row0_col0, #T_617c8_row0_col1, #T_617c8_row0_col2, #T_617c8_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_617c8_row0_col3, #T_617c8_row1_col0, #T_617c8_row1_col1, #T_617c8_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_617c8">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_617c8_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_617c8_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_617c8_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_617c8_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_617c8_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_617c8_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_617c8_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_617c8_row0_col0" class="data row0 col0" >0.076875</td>
#       <td id="T_617c8_row0_col1" class="data row0 col1" >0.010213</td>
#       <td id="T_617c8_row0_col2" class="data row0 col2" >0.101059</td>
#       <td id="T_617c8_row0_col3" class="data row0 col3" >0.989427</td>
#       <td id="T_617c8_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_617c8_row0_col5" class="data row0 col5" >Random Forest 2</td>
#     </tr>
#     <tr>
#       <th id="T_617c8_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_617c8_row1_col0" class="data row1 col0" >0.059357</td>
#       <td id="T_617c8_row1_col1" class="data row1 col1" >0.006002</td>
#       <td id="T_617c8_row1_col2" class="data row1 col2" >0.077473</td>
#       <td id="T_617c8_row1_col3" class="data row1 col3" >0.993709</td>
#       <td id="T_617c8_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_617c8_row1_col5" class="data row1 col5" >Random Forest 2</td>
#     </tr>
#   </tbody>
# </table>

# %%
param = {"max_depth": [20],
        "max_features": [17],
        "min_samples_split": [12]}

random_forest = GridSearchCV(
            estimator=RandomForestRegressor(),
            param_grid= param,
            cv=10,
            n_jobs = -1,
            verbose= 1,
            return_train_score = True,
            scoring="neg_mean_squared_error")

random_forest.fit(X_train, y_train)

best_rf = random_forest.best_estimator_
print(best_rf)

y_pred_test_rf = random_forest.predict(X_test)
y_pred_train_rf = random_forest.predict(X_train)
rf_results_3 = metricas(y_test, y_train, y_pred_test_rf, y_pred_train_rf, "Random Forest 3")
rf_results_3.style.background_gradient(cmap='coolwarm')
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# RandomForestRegressor(max_depth=20, max_features=17, min_samples_split=12)
# <style type="text/css">
# #T_3c56f_row0_col0, #T_3c56f_row0_col1, #T_3c56f_row0_col2, #T_3c56f_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_3c56f_row0_col3, #T_3c56f_row1_col0, #T_3c56f_row1_col1, #T_3c56f_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3c56f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c56f_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_3c56f_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_3c56f_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_3c56f_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_3c56f_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_3c56f_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c56f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c56f_row0_col0" class="data row0 col0" >0.077534</td>
#       <td id="T_3c56f_row0_col1" class="data row0 col1" >0.010511</td>
#       <td id="T_3c56f_row0_col2" class="data row0 col2" >0.102521</td>
#       <td id="T_3c56f_row0_col3" class="data row0 col3" >0.989119</td>
#       <td id="T_3c56f_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_3c56f_row0_col5" class="data row0 col5" >Random Forest 3</td>
#     </tr>
#     <tr>
#       <th id="T_3c56f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3c56f_row1_col0" class="data row1 col0" >0.053917</td>
#       <td id="T_3c56f_row1_col1" class="data row1 col1" >0.005045</td>
#       <td id="T_3c56f_row1_col2" class="data row1 col2" >0.071031</td>
#       <td id="T_3c56f_row1_col3" class="data row1 col3" >0.994712</td>
#       <td id="T_3c56f_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_3c56f_row1_col5" class="data row1 col5" >Random Forest 3</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_results = pd.concat([rf_results_1, rf_results_2, rf_results_3], axis = 0)
df_results
# Out:
#         MAE       MSE      RMSE        R2    set           modelo
# 0  0.077406  0.010436  0.102155  0.989197   test  Random Forest 1
# 1  0.051783  0.004697  0.068537  0.995077  train  Random Forest 1
# 0  0.076875  0.010213  0.101059  0.989427   test  Random Forest 2
# 1  0.059357  0.006002  0.077473  0.993709  train  Random Forest 2
# 0  0.077534  0.010511  0.102521  0.989119   test  Random Forest 3
# 1  0.053917  0.005045  0.071031  0.994712  train  Random Forest 3
