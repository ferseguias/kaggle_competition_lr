# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %%
df = pd.read_csv('../data/train_data_encoded.csv')
print('shape:', df.shape)
df.head(5)
# Out:
# shape: (28942, 7)
#    weight  quality  color  clarity  table_percent  price  depth_percent
# 0    0.30        3      6        1           0.58  6.353          0.624
# 1    1.01        4      5        5           0.56  9.183          0.627
# 2    0.72        4      4        3           0.59  7.983          0.618
# 3    1.08        2      3        1           0.57  8.371          0.632
# 4    0.36        3      3        4           0.59  6.588          0.623

# %%
#split dara train and test
X = df.drop(["price"], axis = 1)
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size   = 0.8, random_state = 42)

print("Datos de entrenamiento")
print("-----------------------")
print(y_train.describe())
print('\n')
print("Datos de testeo")
print("-----------------------")
print(y_test.describe())
# Out:
# Datos de entrenamiento
# -----------------------
# count    23153.000000
# mean         7.992375
# std          0.993806
# min          5.787000
# 25%          7.156000
# 50%          8.082000
# 75%          8.755000
# max          9.842000
# Name: price, dtype: float64
#
#
# Datos de testeo
# -----------------------
# count    5789.000000
# mean        8.006556
# std         0.986775
# min         5.866000
# 25%         7.189000
# 50%         8.089000
# 75%         8.755000
# max         9.841000
# Name: price, dtype: float64

# %%
def metricas(y_test, y_train, y_test_pred, y_train_pred, tipo_modelo):
    resultados = {'MAE': [metrics.mean_absolute_error(y_test, y_test_pred), metrics.mean_absolute_error(y_train, y_train_pred)],
                'MSE': [metrics.mean_squared_error(y_test, y_test_pred), metrics.mean_squared_error(y_train, y_train_pred)],
                'RMSE': [np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)), np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))],
                'R2':  [metrics.r2_score(y_test, y_test_pred), metrics.r2_score(y_train, y_train_pred)],
                 "set": ["test", "train"]}
    df = pd.DataFrame(resultados)
    df["modelo"] = tipo_modelo
    return df

# %%
param = {"max_depth": [14],
        "max_features": [5],
        "min_samples_split": [15]}

random_forest = GridSearchCV(
            estimator=RandomForestRegressor(),
            param_grid= param,
            cv=10,
            n_jobs = -1,
            verbose= 1,
            return_train_score = True,
            scoring="neg_mean_squared_error")

random_forest.fit(X_train, y_train)

best_rf = random_forest.best_estimator_
print(best_rf)

y_pred_test_rf = random_forest.predict(X_test)
y_pred_train_rf = random_forest.predict(X_train)
rf_results_1 = metricas(y_test, y_train, y_pred_test_rf, y_pred_train_rf, "Random Forest 1")
rf_results_1.style.background_gradient(cmap='coolwarm')
# Out:
# Fitting 10 folds for each of 1 candidates, totalling 10 fits
# RandomForestRegressor(max_depth=14, max_features=5, min_samples_split=15)
# <style type="text/css">
# #T_bed02_row0_col0, #T_bed02_row0_col1, #T_bed02_row0_col2, #T_bed02_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_bed02_row0_col3, #T_bed02_row1_col0, #T_bed02_row1_col1, #T_bed02_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_bed02">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bed02_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_bed02_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_bed02_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_bed02_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_bed02_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_bed02_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bed02_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bed02_row0_col0" class="data row0 col0" >0.079479</td>
#       <td id="T_bed02_row0_col1" class="data row0 col1" >0.010954</td>
#       <td id="T_bed02_row0_col2" class="data row0 col2" >0.104662</td>
#       <td id="T_bed02_row0_col3" class="data row0 col3" >0.988748</td>
#       <td id="T_bed02_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_bed02_row0_col5" class="data row0 col5" >Random Forest 1</td>
#     </tr>
#     <tr>
#       <th id="T_bed02_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bed02_row1_col0" class="data row1 col0" >0.063767</td>
#       <td id="T_bed02_row1_col1" class="data row1 col1" >0.007030</td>
#       <td id="T_bed02_row1_col2" class="data row1 col2" >0.083847</td>
#       <td id="T_bed02_row1_col3" class="data row1 col3" >0.992881</td>
#       <td id="T_bed02_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_bed02_row1_col5" class="data row1 col5" >Random Forest 1</td>
#     </tr>
#   </tbody>
# </table>

# %%
param = {"max_depth": [12,18],
        "max_features": [5,6],
        "min_samples_split": [10, 25]}

random_forest = GridSearchCV(
            estimator=RandomForestRegressor(),
            param_grid= param,
            cv=10,
            n_jobs = -1,
            verbose= 1,
            return_train_score = True,
            scoring="neg_mean_squared_error")

random_forest.fit(X_train, y_train)

best_rf = random_forest.best_estimator_
print(best_rf)

y_pred_test_rf = random_forest.predict(X_test)
y_pred_train_rf = random_forest.predict(X_train)
rf_results_2 = metricas(y_test, y_train, y_pred_test_rf, y_pred_train_rf, "Random Forest 2")
rf_results_2.style.background_gradient(cmap='coolwarm')
# Out:
# Fitting 10 folds for each of 8 candidates, totalling 80 fits
# RandomForestRegressor(max_depth=12, max_features=5, min_samples_split=10)
# <style type="text/css">
# #T_c6fd7_row0_col0, #T_c6fd7_row0_col1, #T_c6fd7_row0_col2, #T_c6fd7_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_c6fd7_row0_col3, #T_c6fd7_row1_col0, #T_c6fd7_row1_col1, #T_c6fd7_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_c6fd7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c6fd7_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_c6fd7_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_c6fd7_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_c6fd7_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_c6fd7_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_c6fd7_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c6fd7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c6fd7_row0_col0" class="data row0 col0" >0.079690</td>
#       <td id="T_c6fd7_row0_col1" class="data row0 col1" >0.010973</td>
#       <td id="T_c6fd7_row0_col2" class="data row0 col2" >0.104754</td>
#       <td id="T_c6fd7_row0_col3" class="data row0 col3" >0.988729</td>
#       <td id="T_c6fd7_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_c6fd7_row0_col5" class="data row0 col5" >Random Forest 2</td>
#     </tr>
#     <tr>
#       <th id="T_c6fd7_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c6fd7_row1_col0" class="data row1 col0" >0.065665</td>
#       <td id="T_c6fd7_row1_col1" class="data row1 col1" >0.007434</td>
#       <td id="T_c6fd7_row1_col2" class="data row1 col2" >0.086218</td>
#       <td id="T_c6fd7_row1_col3" class="data row1 col3" >0.992473</td>
#       <td id="T_c6fd7_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_c6fd7_row1_col5" class="data row1 col5" >Random Forest 2</td>
#     </tr>
#   </tbody>
# </table>

# %%
param = {"max_depth": [14],
        "max_features": [6],
        "min_samples_split": [12, 20]}

random_forest = GridSearchCV(
            estimator=RandomForestRegressor(),
            param_grid= param,
            cv=10,
            n_jobs = -1,
            verbose= 1,
            return_train_score = True,
            scoring="neg_mean_squared_error")

random_forest.fit(X_train, y_train)

best_rf = random_forest.best_estimator_
print(best_rf)

y_pred_test_rf = random_forest.predict(X_test)
y_pred_train_rf = random_forest.predict(X_train)
rf_results_3 = metricas(y_test, y_train, y_pred_test_rf, y_pred_train_rf, "Random Forest 3")
rf_results_3.style.background_gradient(cmap='coolwarm')
# Out:
# Fitting 10 folds for each of 2 candidates, totalling 20 fits
# RandomForestRegressor(max_depth=14, max_features=6, min_samples_split=12)
# <style type="text/css">
# #T_72aea_row0_col0, #T_72aea_row0_col1, #T_72aea_row0_col2, #T_72aea_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_72aea_row0_col3, #T_72aea_row1_col0, #T_72aea_row1_col1, #T_72aea_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_72aea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_72aea_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_72aea_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_72aea_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_72aea_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_72aea_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_72aea_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_72aea_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_72aea_row0_col0" class="data row0 col0" >0.079783</td>
#       <td id="T_72aea_row0_col1" class="data row0 col1" >0.011047</td>
#       <td id="T_72aea_row0_col2" class="data row0 col2" >0.105103</td>
#       <td id="T_72aea_row0_col3" class="data row0 col3" >0.988653</td>
#       <td id="T_72aea_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_72aea_row0_col5" class="data row0 col5" >Random Forest 3</td>
#     </tr>
#     <tr>
#       <th id="T_72aea_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_72aea_row1_col0" class="data row1 col0" >0.061125</td>
#       <td id="T_72aea_row1_col1" class="data row1 col1" >0.006468</td>
#       <td id="T_72aea_row1_col2" class="data row1 col2" >0.080421</td>
#       <td id="T_72aea_row1_col3" class="data row1 col3" >0.993451</td>
#       <td id="T_72aea_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_72aea_row1_col5" class="data row1 col5" >Random Forest 3</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_results = pd.concat([rf_results_1, rf_results_2, rf_results_3], axis = 0)
df_results
# Out:
#         MAE       MSE      RMSE        R2    set           modelo
# 0  0.079479  0.010954  0.104662  0.988748   test  Random Forest 1
# 1  0.063767  0.007030  0.083847  0.992881  train  Random Forest 1
# 0  0.079690  0.010973  0.104754  0.988729   test  Random Forest 2
# 1  0.065665  0.007434  0.086218  0.992473  train  Random Forest 2
# 0  0.079783  0.011047  0.105103  0.988653   test  Random Forest 3
# 1  0.061125  0.006468  0.080421  0.993451  train  Random Forest 3
