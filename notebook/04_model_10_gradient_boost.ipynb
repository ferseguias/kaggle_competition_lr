# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn import metrics

# %%
df = pd.read_csv('../data/train_data_encoded_full.csv')
print('shape:', df.shape)
df.head(5)
# Out:
# shape: (39829, 7)
#    weight  quality  color  clarity  table_percent     price  depth_percent
# 0    0.30        3      6        1           0.58  1.848927          0.624
# 1    1.01        4      5        5           0.56  2.217354          0.627
# 2    0.72        4      4        3           0.59  2.077314          0.618
# 3    1.08        2      3        1           0.57  2.124773          0.632
# 4    0.36        3      3        4           0.59  1.885250          0.623

# %%
#split dara train and test
X = df.drop(["price"], axis = 1)
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size   = 0.8, random_state = 42)

print("Datos de entrenamiento")
print("-----------------------")
print(y_train.describe())
print('\n')
print("Datos de testeo")
print("-----------------------")
print(y_test.describe())
# Out:
# Datos de entrenamiento
# -----------------------
# count    31863.000000
# mean         2.042597
# std          0.131438
# min          1.755614
# 25%          1.923080
# 50%          2.050270
# 75%          2.149201
# max          2.286659
# Name: price, dtype: float64
#
#
# Datos de testeo
# -----------------------
# count    7966.000000
# mean        2.042922
# std         0.131004
# min         1.762331
# 25%         1.924687
# 50%         2.051106
# 75%         2.148734
# max         2.286659
# Name: price, dtype: float64

# %%
def metricas(y_test, y_train, y_test_pred, y_train_pred, tipo_modelo):
    resultados = {'MAE': [metrics.mean_absolute_error(y_test, y_test_pred), metrics.mean_absolute_error(y_train, y_train_pred)],
                'MSE': [metrics.mean_squared_error(y_test, y_test_pred), metrics.mean_squared_error(y_train, y_train_pred)],
                'RMSE': [np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)), np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))],
                'R2':  [metrics.r2_score(y_test, y_test_pred), metrics.r2_score(y_train, y_train_pred)],
                 "set": ["test", "train"]}
    df = pd.DataFrame(resultados)
    df["modelo"] = tipo_modelo
    return df

# %%
gb = GradientBoostingRegressor(n_estimators=100, loss='squared_error', learning_rate=0.1, max_depth=8, random_state=0, criterion='friedman_mse')
gb.fit(X_train, y_train)

y_pred_gb_test= gb.predict(X_test)
y_pred_gb_train= gb.predict(X_train)

results_gradient_1 = metricas(y_test, y_train, y_pred_gb_test, y_pred_gb_train, "Gradient 1")
results_gradient_1.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_a87e0_row0_col0, #T_a87e0_row0_col1, #T_a87e0_row0_col2, #T_a87e0_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_a87e0_row0_col3, #T_a87e0_row1_col0, #T_a87e0_row1_col1, #T_a87e0_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_a87e0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a87e0_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_a87e0_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_a87e0_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_a87e0_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_a87e0_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_a87e0_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a87e0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_a87e0_row0_col0" class="data row0 col0" >0.009405</td>
#       <td id="T_a87e0_row0_col1" class="data row0 col1" >0.000161</td>
#       <td id="T_a87e0_row0_col2" class="data row0 col2" >0.012691</td>
#       <td id="T_a87e0_row0_col3" class="data row0 col3" >0.990615</td>
#       <td id="T_a87e0_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_a87e0_row0_col5" class="data row0 col5" >Gradient 1</td>
#     </tr>
#     <tr>
#       <th id="T_a87e0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_a87e0_row1_col0" class="data row1 col0" >0.008093</td>
#       <td id="T_a87e0_row1_col1" class="data row1 col1" >0.000119</td>
#       <td id="T_a87e0_row1_col2" class="data row1 col2" >0.010915</td>
#       <td id="T_a87e0_row1_col3" class="data row1 col3" >0.993103</td>
#       <td id="T_a87e0_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_a87e0_row1_col5" class="data row1 col5" >Gradient 1</td>
#     </tr>
#   </tbody>
# </table>

# %%
gb = GradientBoostingRegressor(n_estimators=120, loss='squared_error', learning_rate=0.1, max_depth=7, random_state=0, criterion='friedman_mse')
gb.fit(X_train, y_train)

y_pred_gb_test= gb.predict(X_test)
y_pred_gb_train= gb.predict(X_train)

results_gradient_2 = metricas(y_test, y_train, y_pred_gb_test, y_pred_gb_train, "Gradient 2")
results_gradient_2.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_36dcd_row0_col0, #T_36dcd_row0_col1, #T_36dcd_row0_col2, #T_36dcd_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_36dcd_row0_col3, #T_36dcd_row1_col0, #T_36dcd_row1_col1, #T_36dcd_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_36dcd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_36dcd_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_36dcd_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_36dcd_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_36dcd_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_36dcd_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_36dcd_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_36dcd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_36dcd_row0_col0" class="data row0 col0" >0.009352</td>
#       <td id="T_36dcd_row0_col1" class="data row0 col1" >0.000158</td>
#       <td id="T_36dcd_row0_col2" class="data row0 col2" >0.012563</td>
#       <td id="T_36dcd_row0_col3" class="data row0 col3" >0.990802</td>
#       <td id="T_36dcd_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_36dcd_row0_col5" class="data row0 col5" >Gradient 2</td>
#     </tr>
#     <tr>
#       <th id="T_36dcd_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_36dcd_row1_col0" class="data row1 col0" >0.008523</td>
#       <td id="T_36dcd_row1_col1" class="data row1 col1" >0.000130</td>
#       <td id="T_36dcd_row1_col2" class="data row1 col2" >0.011413</td>
#       <td id="T_36dcd_row1_col3" class="data row1 col3" >0.992460</td>
#       <td id="T_36dcd_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_36dcd_row1_col5" class="data row1 col5" >Gradient 2</td>
#     </tr>
#   </tbody>
# </table>

# %%
gb = GradientBoostingRegressor(n_estimators=125, loss='squared_error', learning_rate=0.15, max_depth=6, random_state=0, criterion='friedman_mse')
gb.fit(X_train, y_train)

y_pred_gb_test= gb.predict(X_test)
y_pred_gb_train= gb.predict(X_train)

results_gradient_3 = metricas(y_test, y_train, y_pred_gb_test, y_pred_gb_train, "Gradient 3")
results_gradient_3.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f4ff0_row0_col0, #T_f4ff0_row0_col1, #T_f4ff0_row0_col2, #T_f4ff0_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f4ff0_row0_col3, #T_f4ff0_row1_col0, #T_f4ff0_row1_col1, #T_f4ff0_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_f4ff0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f4ff0_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f4ff0_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f4ff0_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f4ff0_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f4ff0_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_f4ff0_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f4ff0_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f4ff0_row0_col0" class="data row0 col0" >0.009426</td>
#       <td id="T_f4ff0_row0_col1" class="data row0 col1" >0.000159</td>
#       <td id="T_f4ff0_row0_col2" class="data row0 col2" >0.012613</td>
#       <td id="T_f4ff0_row0_col3" class="data row0 col3" >0.990729</td>
#       <td id="T_f4ff0_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_f4ff0_row0_col5" class="data row0 col5" >Gradient 3</td>
#     </tr>
#     <tr>
#       <th id="T_f4ff0_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f4ff0_row1_col0" class="data row1 col0" >0.008798</td>
#       <td id="T_f4ff0_row1_col1" class="data row1 col1" >0.000137</td>
#       <td id="T_f4ff0_row1_col2" class="data row1 col2" >0.011720</td>
#       <td id="T_f4ff0_row1_col3" class="data row1 col3" >0.992049</td>
#       <td id="T_f4ff0_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_f4ff0_row1_col5" class="data row1 col5" >Gradient 3</td>
#     </tr>
#   </tbody>
# </table>

# %%
gb = GradientBoostingRegressor(n_estimators=100, loss='squared_error', learning_rate=0.15, max_depth=7, random_state=0, criterion='squared_error')
gb.fit(X_train, y_train)

y_pred_gb_test= gb.predict(X_test)
y_pred_gb_train= gb.predict(X_train)

results_gradient_4 = metricas(y_test, y_train, y_pred_gb_test, y_pred_gb_train, "Gradient 4")
results_gradient_4.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_fad47_row0_col0, #T_fad47_row0_col1, #T_fad47_row0_col2, #T_fad47_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_fad47_row0_col3, #T_fad47_row1_col0, #T_fad47_row1_col1, #T_fad47_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_fad47">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_fad47_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_fad47_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_fad47_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_fad47_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_fad47_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_fad47_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fad47_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_fad47_row0_col0" class="data row0 col0" >0.009431</td>
#       <td id="T_fad47_row0_col1" class="data row0 col1" >0.000161</td>
#       <td id="T_fad47_row0_col2" class="data row0 col2" >0.012696</td>
#       <td id="T_fad47_row0_col3" class="data row0 col3" >0.990606</td>
#       <td id="T_fad47_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_fad47_row0_col5" class="data row0 col5" >Gradient 4</td>
#     </tr>
#     <tr>
#       <th id="T_fad47_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_fad47_row1_col0" class="data row1 col0" >0.008460</td>
#       <td id="T_fad47_row1_col1" class="data row1 col1" >0.000128</td>
#       <td id="T_fad47_row1_col2" class="data row1 col2" >0.011324</td>
#       <td id="T_fad47_row1_col3" class="data row1 col3" >0.992577</td>
#       <td id="T_fad47_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_fad47_row1_col5" class="data row1 col5" >Gradient 4</td>
#     </tr>
#   </tbody>
# </table>

# %%
gb = GradientBoostingRegressor(n_estimators=110, loss='squared_error', learning_rate=0.12, max_depth=7, random_state=0, criterion='squared_error')
gb.fit(X_train, y_train)

y_pred_gb_test= gb.predict(X_test)
y_pred_gb_train= gb.predict(X_train)

results_gradient_5 = metricas(y_test, y_train, y_pred_gb_test, y_pred_gb_train, "Gradient 5")
results_gradient_5.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_17e25_row0_col0, #T_17e25_row0_col1, #T_17e25_row0_col2, #T_17e25_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_17e25_row0_col3, #T_17e25_row1_col0, #T_17e25_row1_col1, #T_17e25_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_17e25">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_17e25_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_17e25_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_17e25_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_17e25_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_17e25_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_17e25_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_17e25_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_17e25_row0_col0" class="data row0 col0" >0.009361</td>
#       <td id="T_17e25_row0_col1" class="data row0 col1" >0.000158</td>
#       <td id="T_17e25_row0_col2" class="data row0 col2" >0.012582</td>
#       <td id="T_17e25_row0_col3" class="data row0 col3" >0.990774</td>
#       <td id="T_17e25_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_17e25_row0_col5" class="data row0 col5" >Gradient 5</td>
#     </tr>
#     <tr>
#       <th id="T_17e25_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_17e25_row1_col0" class="data row1 col0" >0.008511</td>
#       <td id="T_17e25_row1_col1" class="data row1 col1" >0.000130</td>
#       <td id="T_17e25_row1_col2" class="data row1 col2" >0.011401</td>
#       <td id="T_17e25_row1_col3" class="data row1 col3" >0.992476</td>
#       <td id="T_17e25_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_17e25_row1_col5" class="data row1 col5" >Gradient 5</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_results = pd.concat([results_gradient_1, results_gradient_2, results_gradient_3, results_gradient_4, results_gradient_5], axis = 0)
df_results
# Out:
#         MAE       MSE      RMSE        R2    set      modelo
# 0  0.009405  0.000161  0.012691  0.990615   test  Gradient 1
# 1  0.008093  0.000119  0.010915  0.993103  train  Gradient 1
# 0  0.009352  0.000158  0.012563  0.990802   test  Gradient 2
# 1  0.008523  0.000130  0.011413  0.992460  train  Gradient 2
# 0  0.009426  0.000159  0.012613  0.990729   test  Gradient 3
# 1  0.008798  0.000137  0.011720  0.992049  train  Gradient 3
# 0  0.009431  0.000161  0.012696  0.990606   test  Gradient 4
# 1  0.008460  0.000128  0.011324  0.992577  train  Gradient 4
# 0  0.009361  0.000158  0.012582  0.990774   test  Gradient 5
# 1  0.008511  0.000130  0.011401  0.992476  train  Gradient 5
