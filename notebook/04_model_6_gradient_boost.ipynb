# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %%
df = pd.read_csv('../data/train_data_encoded.csv')
print('shape:', df.shape)
df.head(5)
# Out:
# shape: (28942, 7)
#    weight  quality  color  clarity  table_percent  price  depth_percent
# 0    0.30        3      6        1           0.58  6.353          0.624
# 1    1.01        4      5        5           0.56  9.183          0.627
# 2    0.72        4      4        3           0.59  7.983          0.618
# 3    1.08        2      3        1           0.57  8.371          0.632
# 4    0.36        3      3        4           0.59  6.588          0.623

# %%
#reduce predictor variables
df = df[['weight', 'quality', 'color', 'clarity', 'price']]
df
# Out:
#        weight  quality  color  clarity  price
# 0        0.30        3      6        1  6.353
# 1        1.01        4      5        5  9.183
# 2        0.72        4      4        3  7.983
# 3        1.08        2      3        1  8.371
# 4        0.36        3      3        4  6.588
# ...       ...      ...    ...      ...    ...
# 28937    1.52        3      6        1  9.093
# 28938    0.37        3      4        3  6.545
# 28939    1.01        3      4        4  8.854
# 28940    0.80        1      3        1  7.768
# 28941    1.30        3      1        3  8.771
#
# [28942 rows x 5 columns]

# %%
#split dara train and test
X = df.drop(["price"], axis = 1)
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size   = 0.8, random_state = 42)

print("Datos de entrenamiento")
print("-----------------------")
print(y_train.describe())
print('\n')
print("Datos de testeo")
print("-----------------------")
print(y_test.describe())
# Out:
# Datos de entrenamiento
# -----------------------
# count    23153.000000
# mean         7.992375
# std          0.993806
# min          5.787000
# 25%          7.156000
# 50%          8.082000
# 75%          8.755000
# max          9.842000
# Name: price, dtype: float64
#
#
# Datos de testeo
# -----------------------
# count    5789.000000
# mean        8.006556
# std         0.986775
# min         5.866000
# 25%         7.189000
# 50%         8.089000
# 75%         8.755000
# max         9.841000
# Name: price, dtype: float64

# %%
def metricas(y_test, y_train, y_test_pred, y_train_pred, tipo_modelo):
    resultados = {'MAE': [metrics.mean_absolute_error(y_test, y_test_pred), metrics.mean_absolute_error(y_train, y_train_pred)],
                'MSE': [metrics.mean_squared_error(y_test, y_test_pred), metrics.mean_squared_error(y_train, y_train_pred)],
                'RMSE': [np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)), np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))],
                'R2':  [metrics.r2_score(y_test, y_test_pred), metrics.r2_score(y_train, y_train_pred)],
                 "set": ["test", "train"]}
    df = pd.DataFrame(resultados)
    df["modelo"] = tipo_modelo
    return df

# %%
gb = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=9, random_state=0, criterion='squared_error')
gb.fit(X_train, y_train)

y_pred_gb_test= gb.predict(X_test)
y_pred_gb_train= gb.predict(X_train)

results_gradient_1 = metricas(y_test, y_train, y_pred_gb_test, y_pred_gb_train, "Gradient 1")
results_gradient_1.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_95764_row0_col0, #T_95764_row0_col1, #T_95764_row0_col2, #T_95764_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_95764_row0_col3, #T_95764_row1_col0, #T_95764_row1_col1, #T_95764_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_95764">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95764_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_95764_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_95764_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_95764_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_95764_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_95764_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95764_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95764_row0_col0" class="data row0 col0" >0.079641</td>
#       <td id="T_95764_row0_col1" class="data row0 col1" >0.011105</td>
#       <td id="T_95764_row0_col2" class="data row0 col2" >0.105382</td>
#       <td id="T_95764_row0_col3" class="data row0 col3" >0.988593</td>
#       <td id="T_95764_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_95764_row0_col5" class="data row0 col5" >Gradient 1</td>
#     </tr>
#     <tr>
#       <th id="T_95764_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_95764_row1_col0" class="data row1 col0" >0.063971</td>
#       <td id="T_95764_row1_col1" class="data row1 col1" >0.007366</td>
#       <td id="T_95764_row1_col2" class="data row1 col2" >0.085823</td>
#       <td id="T_95764_row1_col3" class="data row1 col3" >0.992542</td>
#       <td id="T_95764_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_95764_row1_col5" class="data row1 col5" >Gradient 1</td>
#     </tr>
#   </tbody>
# </table>

# %%
gb = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=4, random_state=0, criterion='squared_error')
gb.fit(X_train, y_train)

y_pred_gb_test= gb.predict(X_test)
y_pred_gb_train= gb.predict(X_train)

results_gradient_2 = metricas(y_test, y_train, y_pred_gb_test, y_pred_gb_train, "Gradient 2")
results_gradient_2.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_7e616_row0_col0, #T_7e616_row0_col1, #T_7e616_row0_col2, #T_7e616_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_7e616_row0_col3, #T_7e616_row1_col0, #T_7e616_row1_col1, #T_7e616_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_7e616">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7e616_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_7e616_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_7e616_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_7e616_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_7e616_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_7e616_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7e616_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7e616_row0_col0" class="data row0 col0" >0.080288</td>
#       <td id="T_7e616_row0_col1" class="data row0 col1" >0.011072</td>
#       <td id="T_7e616_row0_col2" class="data row0 col2" >0.105226</td>
#       <td id="T_7e616_row0_col3" class="data row0 col3" >0.988627</td>
#       <td id="T_7e616_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_7e616_row0_col5" class="data row0 col5" >Gradient 2</td>
#     </tr>
#     <tr>
#       <th id="T_7e616_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_7e616_row1_col0" class="data row1 col0" >0.078663</td>
#       <td id="T_7e616_row1_col1" class="data row1 col1" >0.010716</td>
#       <td id="T_7e616_row1_col2" class="data row1 col2" >0.103516</td>
#       <td id="T_7e616_row1_col3" class="data row1 col3" >0.989150</td>
#       <td id="T_7e616_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_7e616_row1_col5" class="data row1 col5" >Gradient 2</td>
#     </tr>
#   </tbody>
# </table>

# %%
gb = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=7, random_state=0, criterion='squared_error')
gb.fit(X_train, y_train)

y_pred_gb_test= gb.predict(X_test)
y_pred_gb_train= gb.predict(X_train)

results_gradient_3 = metricas(y_test, y_train, y_pred_gb_test, y_pred_gb_train, "Gradient 3")
results_gradient_3.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_6e460_row0_col0, #T_6e460_row0_col1, #T_6e460_row0_col2, #T_6e460_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_6e460_row0_col3, #T_6e460_row1_col0, #T_6e460_row1_col1, #T_6e460_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_6e460">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_6e460_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_6e460_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_6e460_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_6e460_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_6e460_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_6e460_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6e460_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6e460_row0_col0" class="data row0 col0" >0.077512</td>
#       <td id="T_6e460_row0_col1" class="data row0 col1" >0.010482</td>
#       <td id="T_6e460_row0_col2" class="data row0 col2" >0.102381</td>
#       <td id="T_6e460_row0_col3" class="data row0 col3" >0.989233</td>
#       <td id="T_6e460_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_6e460_row0_col5" class="data row0 col5" >Gradient 3</td>
#     </tr>
#     <tr>
#       <th id="T_6e460_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6e460_row1_col0" class="data row1 col0" >0.070554</td>
#       <td id="T_6e460_row1_col1" class="data row1 col1" >0.008739</td>
#       <td id="T_6e460_row1_col2" class="data row1 col2" >0.093483</td>
#       <td id="T_6e460_row1_col3" class="data row1 col3" >0.991151</td>
#       <td id="T_6e460_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_6e460_row1_col5" class="data row1 col5" >Gradient 3</td>
#     </tr>
#   </tbody>
# </table>

# %%
param = {"criterion": ['squared_error'],
        "n_estimators": [100, 200, 300, 400, 500],
        "learning_rate": [0.1, 0.15, 0.05],
        "random_state": [0],
        "max_depth": [6, 8, 12]}

gradien_boost = GridSearchCV(
            estimator=GradientBoostingRegressor(),
            param_grid= param,
            cv=10,
            n_jobs = -1,
            verbose= 1,
            return_train_score = True,
            scoring="neg_mean_squared_error")

gradien_boost.fit(X_train, y_train)

best_gb = gradien_boost.best_estimator_
print(best_gb)


y_pred_test_gb = gradien_boost.predict(X_test)
y_pred_train_gb = gradien_boost.predict(X_train)
results_gradient_4 = metricas(y_test, y_train, y_pred_test_gb, y_pred_train_gb, "Gradient 4")
results_gradient_4.style.background_gradient(cmap='coolwarm')
# Out:
# Fitting 10 folds for each of 45 candidates, totalling 450 fits
# GradientBoostingRegressor(criterion='squared_error', learning_rate=0.05,
#                           max_depth=6, n_estimators=200, random_state=0)
# <style type="text/css">
# #T_2063b_row0_col0, #T_2063b_row0_col1, #T_2063b_row0_col2, #T_2063b_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_2063b_row0_col3, #T_2063b_row1_col0, #T_2063b_row1_col1, #T_2063b_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_2063b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2063b_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_2063b_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_2063b_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_2063b_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_2063b_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_2063b_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2063b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2063b_row0_col0" class="data row0 col0" >0.077533</td>
#       <td id="T_2063b_row0_col1" class="data row0 col1" >0.010450</td>
#       <td id="T_2063b_row0_col2" class="data row0 col2" >0.102225</td>
#       <td id="T_2063b_row0_col3" class="data row0 col3" >0.989266</td>
#       <td id="T_2063b_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_2063b_row0_col5" class="data row0 col5" >Gradient 4</td>
#     </tr>
#     <tr>
#       <th id="T_2063b_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2063b_row1_col0" class="data row1 col0" >0.073029</td>
#       <td id="T_2063b_row1_col1" class="data row1 col1" >0.009316</td>
#       <td id="T_2063b_row1_col2" class="data row1 col2" >0.096517</td>
#       <td id="T_2063b_row1_col3" class="data row1 col3" >0.990568</td>
#       <td id="T_2063b_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_2063b_row1_col5" class="data row1 col5" >Gradient 4</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_results = pd.concat([results_gradient_1, results_gradient_2, results_gradient_3, results_gradient_4], axis = 0)
df_results
# Out:
#         MAE       MSE      RMSE        R2    set      modelo
# 0  0.079641  0.011105  0.105382  0.988593   test  Gradient 1
# 1  0.063971  0.007366  0.085823  0.992542  train  Gradient 1
# 0  0.080288  0.011072  0.105226  0.988627   test  Gradient 2
# 1  0.078663  0.010716  0.103516  0.989150  train  Gradient 2
# 0  0.077512  0.010482  0.102381  0.989233   test  Gradient 3
# 1  0.070554  0.008739  0.093483  0.991151  train  Gradient 3
# 0  0.077533  0.010450  0.102225  0.989266   test  Gradient 4
# 1  0.073029  0.009316  0.096517  0.990568  train  Gradient 4
