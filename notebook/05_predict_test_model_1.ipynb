# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import GridSearchCV
from sklearn import metrics

# %%
df = pd.read_csv('../data/train_data_encoded.csv')
print('shape:', df.shape)
df.head(5)
# Out:
# shape: (28942, 7)
#    weight  quality  color  clarity  table_percent  price  depth_percent
# 0    0.30        3      6        1           0.58  6.353          0.624
# 1    1.01        4      5        5           0.56  9.183          0.627
# 2    0.72        4      4        3           0.59  7.983          0.618
# 3    1.08        2      3        1           0.57  8.371          0.632
# 4    0.36        3      3        4           0.59  6.588          0.623

# %%
#split dara train and test
X = df.drop(["price"], axis = 1)
y = df['price']

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size   = 0.8, random_state = 42)

print("Datos de entrenamiento")
print("-----------------------")
print(y_train.describe())
print('\n')
print("Datos de testeo")
print("-----------------------")
print(y_test.describe())
# Out:
# Datos de entrenamiento
# -----------------------
# count    23153.000000
# mean         7.992375
# std          0.993806
# min          5.787000
# 25%          7.156000
# 50%          8.082000
# 75%          8.755000
# max          9.842000
# Name: price, dtype: float64
#
#
# Datos de testeo
# -----------------------
# count    5789.000000
# mean        8.006556
# std         0.986775
# min         5.866000
# 25%         7.189000
# 50%         8.089000
# 75%         8.755000
# max         9.841000
# Name: price, dtype: float64

# %%
def metricas(y_test, y_train, y_test_pred, y_train_pred, tipo_modelo):
    resultados = {'MAE': [metrics.mean_absolute_error(y_test, y_test_pred), metrics.mean_absolute_error(y_train, y_train_pred)],
                'MSE': [metrics.mean_squared_error(y_test, y_test_pred), metrics.mean_squared_error(y_train, y_train_pred)],
                'RMSE': [np.sqrt(metrics.mean_squared_error(y_test, y_test_pred)), np.sqrt(metrics.mean_squared_error(y_train, y_train_pred))],
                'R2':  [metrics.r2_score(y_test, y_test_pred), metrics.r2_score(y_train, y_train_pred)],
                 "set": ["test", "train"]}
    df = pd.DataFrame(resultados)
    df["modelo"] = tipo_modelo
    return df

# %%
gb = GradientBoostingRegressor(n_estimators=100, learning_rate=0.1, max_depth=8, random_state=0, criterion='squared_error')
gb.fit(X_train, y_train)

y_pred_gb_test= gb.predict(X_test)
y_pred_gb_train= gb.predict(X_train)

results_gradient_3 = metricas(y_test, y_train, y_pred_gb_test, y_pred_gb_train, "Gradient 3")
results_gradient_3.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_30f19_row0_col0, #T_30f19_row0_col1, #T_30f19_row0_col2, #T_30f19_row1_col3 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_30f19_row0_col3, #T_30f19_row1_col0, #T_30f19_row1_col1, #T_30f19_row1_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_30f19">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_30f19_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_30f19_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_30f19_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_30f19_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_30f19_level0_col4" class="col_heading level0 col4" >set</th>
#       <th id="T_30f19_level0_col5" class="col_heading level0 col5" >modelo</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_30f19_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_30f19_row0_col0" class="data row0 col0" >0.074649</td>
#       <td id="T_30f19_row0_col1" class="data row0 col1" >0.009997</td>
#       <td id="T_30f19_row0_col2" class="data row0 col2" >0.099986</td>
#       <td id="T_30f19_row0_col3" class="data row0 col3" >0.989731</td>
#       <td id="T_30f19_row0_col4" class="data row0 col4" >test</td>
#       <td id="T_30f19_row0_col5" class="data row0 col5" >Gradient 3</td>
#     </tr>
#     <tr>
#       <th id="T_30f19_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_30f19_row1_col0" class="data row1 col0" >0.058890</td>
#       <td id="T_30f19_row1_col1" class="data row1 col1" >0.006233</td>
#       <td id="T_30f19_row1_col2" class="data row1 col2" >0.078951</td>
#       <td id="T_30f19_row1_col3" class="data row1 col3" >0.993688</td>
#       <td id="T_30f19_row1_col4" class="data row1 col4" >train</td>
#       <td id="T_30f19_row1_col5" class="data row1 col5" >Gradient 3</td>
#     </tr>
#   </tbody>
# </table>

# %%
df_test = pd.read_csv('../data/test_data_encoded.csv')
df_test
# Out:
#        weight  quality  color  clarity  table_percent  depth_percent
# 0        0.32        4      1        2          0.580          0.605
# 1        1.24        3      1        2          0.600          0.629
# 2        1.66        3      6        2          0.590          0.620
# 3        0.75        3      6        1          0.560          0.606
# 4        1.50        0      5        1          0.550          0.648
# ...       ...      ...    ...      ...            ...            ...
# 13480    1.10        3      3        2          0.600          0.596
# 13481    0.90        2      6        2          0.600          0.621
# 13482    0.30        4      4        3          0.533          0.621
# 13483    1.25        4      1        2          0.590          0.596
# 13484    0.81        3      4        2          0.580          0.616
#
# [13485 rows x 6 columns]

# %%
#predict test to submit competition
y_pred_gb_test = gb.predict(df_test)
submission_1 = pd.DataFrame(y_pred_gb_test).reset_index()
print('shape:', y_pred_gb_test.shape)
submission_1.columns = ['id', 'price']
submission_1
# Out:
# shape: (13485,)
#           id     price
# 0          0  6.131006
# 1          1  8.602525
# 2          2  9.466583
# 3          3  7.872835
# 4          4  9.067332
# ...      ...       ...
# 13480  13480  8.559315
# 13481  13481  8.380205
# 13482  13482  6.496367
# 13483  13483  8.653308
# 13484  13484  8.009475
#
# [13485 rows x 2 columns]

# %%
submission_1.to_csv('../output/submission_1_fs.csv', index=False)
